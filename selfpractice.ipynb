# %%
#Topic 1: Introduction to Programming & Python
# ============================================================
# CODE EXAMPLE 1.1b: Programming as precise instructions
# This shows how Python follows each instruction one by one
# ============================================================

# Step 1: Store the user's name
student_name = "Farah"

# Step 2: Store the course name
course_name = "Data science"

# Step 3: Display a personalised welcome message
print("Welcome, ", student_name)
print("You are enrolled in ", course_name)
print("Enjoy your learning!")
# Out:
# Welcome,  Farah
# You are enrolled in  Data science
# Enjoy your learning!

# %%
# CLASS ACTIVITY 1.1a
# Replace "Your Name" with your actual name
# Replace each "Goal X" with something real you want to build

my_name = "New Student"

print("My name is:", my_name)
print("With Python, I want to:")
print("   1: Build something")
print("   2: Build another thing")
print("   3: Yet another thing")
# Out:
# My name is: New Student
# With Python, I want to:
#    1: Build something
#    2: Build another thing
#    3: Yet another thing

# %%
# ============================================================
# CODE EXAMPLE 1.2a: Exploring Python's versatility
# This shows how Python handles different types of tasks
# ============================================================

# --- Task 1: Maths (like a data scientist would use) ---
scores = [85, 92, 78, 95, 88]            # A list of student scores
average = sum(scores) / len(scores)      # Calculate the average
print("The average of these numbers is:", average)         # Display result

# --- Task 2: Text processing (like web development) ---
message = "python is amazing"
print("Formatted:", message.upper())      # 'Python Is Amazing'

# --- Task 3: Decision making (like automation) ---
file_size_mb = 99.9
if file_size_mb > 100:
    print("File is large; consider compressing it.")
else:
    print("File size is acceptable.")
# Out:
# The average of these numbers is: 87.6
# Formatted: PYTHON IS AMAZING
# File size is acceptable.

# %%
# CLASS ACTIVITY 1.2a
# A list of Python applications
python_uses = [
    "Web Development",
    "Data Science",
    "Automation",
    "Software Dvlpt.",
    "Machine Learning"
    # Add two more applications below:
    # "...",
    # "..."
]

print("Python is used for:")

for use in python_uses:
    print("*", use)

print("\nTotal domains =", len(python_uses))
# Out:
# Python is used for:
# * Web Development
# * Data Science
# * Automation
# * Software Dvlpt.
# * Machine Learning
#
# Total domains = 5

# %%
# CODE EXAMPLE 1.5a: A complete introductory script
# This is the kind of script you would save as hello.py
# and run from the terminal
# ============================================================

# Display a welcome banner
print("=" * 40)
print("    Welcome to My First Python Script")
print("=" * 40)

# Ask the user for their name
name = input("Please enter your name: ")

# Ask the user for their age
age = input("Please enter your age: ")

# Display a personalised message
print("\nHello,", name + "!")
print("You are", age, "years old.")
print("Welcome to Python Programming!")
# Out:
# ...
#     Welcome to My First Python Script
# ...
#
# Hello, Haddiee!
# You are 52 years old.
# Welcome to Python Programming!

# %% [markdown]
# REPL stands for:
#
# Read → Evaluate → Print → Loop
#
# A script file is a file where you save several lines of Python code and run them together.
#
# ### The REPL (Interactive Mode)
# - Access by typing `python` in the terminal
# - Type one line → press Enter → see immediate result
# - Great for: quick experiments, testing ideas, calculator-style use
# - Downside: code is lost when you close the terminal
#
# ### Script Files (.py)
# - Write code in a `.py` file and run with `python filename.py`
# - Great for: real programs, multi-line code, code you want to save
# - Code is permanently saved
#
# **Rule of thumb:** Use the REPL to explore; use scripts to build.

# %%
# CODE EXAMPLE 1.6a: REPL-style quick experiments
# These are the kinds of things you would test in the REPL
# ============================================================

# Quick maths
print(2 + 2)            # → 4
print(10 / 3)           # → 3.3333...
print(10 // 3)          # → 3  (floor division)
print(10 % 3)           # → 1  (remainder)

# Quick string test
print("hello".upper())  # → HELLO
print(len("Python"))    # → 6 (number of characters)
print("trying out the .upper function".upper())
# Out:
# 4
# 3.3333333333333335
# 3
# 1
# HELLO
# 6
# TRYING OUT THE .UPPER FUNCTION

# %% [markdown]
# When using the .upper() function immediately after a string, do not put space and comma after it. Instead, type the .upper immediately after the closing double-quote.

# %%
# PRACTICE QUESTION — Topic 1
# Write a Python program that demonstrates your understanding of all micro-topics in Topic 1.
# 1. Print a welcome banner (3 lines using = characters)
# 2. Ask the user for their name, age, and favourite Python application (e.g., data science)
# 3. Display a summary message that includes all three pieces of information
# 4. Print a list of at least 4 Python applications (use a loop)
# 5. End with a motivational closing message

# Step 1: Print welcome banner
print("=" * 50)
print("Hello and welcome".upper())
print("=" * 50)

# Step 2: Collect user information
name = input("What were you named at birth?")
age = input("How long have you been in existence for?")
fav_python_app = input("What's your favorite way to use python?")

# Step 3: Display summary
print(name)
print(age)
print(fav_python_app)

# Step 4: Print Python applications list
python_apps = ["Data Science", "ML", "AI", "Robotics"]
print("\nPython applications include: ")

for apps in python_apps:
    print(">", apps)

# Step 5: Closing message
print("\nEnjoy your python lesson!")
# Out:
# ...
# HELLO AND WELCOME
# ...
# Hadiyah Raji
# 25
# Data Science
#
# Python applications include:
# > Data Science
# > ML
# > AI
# > Robotics
#
# Enjoy your python lesson!

# %%
# MINI PROJECT: Python Identity Card
# Write your solution here
print(":" * 50)
print("python learner identity card".upper())
print(":" * 50)

# Collect user information
full_name = input("Enter your full name: ")
age = input("Enter your age: ")
country = input("Enter your country: ")
focus_area = input("Favourite Python use case: ")
course_goal = input("Your goal for this course: ")

# Display the identity card
print("Name :", full_name)
print("Age :", age)
print("Country : ", country)
print("Focus :", focus_area)
print("Goal :", course_goal)

print("\nEvery expert was once a beginner.")
# Out:
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# PYTHON LEARNER IDENTITY CARD
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# Name : Hadiyah Raji
# Age : 25
# Country :  Bahrain
# Focus : Data Science
# Goal : Learn python basics
#
# Every expert was once a beginner.

# %% [markdown]
# ###### ==========================================
# ###### PYTHON LEARNER IDENTITY CARD
# ###### ==========================================
# Name : Amara Johnson
# Age : 22
# Country : Ghana
# Focus : Data Science
# Goal : Build a data dashboard
#
# "Every expert was once a beginner."

# %% [markdown]
# ### Python Syntax & Basics
# ##### Learn the rules that make Python code work - indentation, comments, and the print() and input() functions. By the end you'll be writing and running your own Python scripts confidently.

# %%
# CLASS ACTIVITY 2.1b 
# Write a program that checks if a number is positive, negative, or zero using proper indentation. Use if, elif, and else.

number = -7   # Try changing this to 0 or a positive number
if number =
