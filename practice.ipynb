# %%
print("hello world")

print("I am learning python")

print("Programming is fun")
# Out:
# hello world
# I am learning python
# Programming is fun

# %% [markdown]
# # Hello, I'm Hadiyah
#
# ## Hello, I'm Hadiyah
#
# ### Hello, I'm Hadiyah
#
# #### Hello, I'm Hadiyah
#
# Hello, I'm Hadiyah
#
# - LIST ONE
#
# - LIST TWO

# %%
print("This is me printing a string in python")
print(5)
print("5 + 5")
# Out:
# This is me printing a string in python
# 5
# 5 + 5

# %%
student_name = "Hadiyah"
course_name = "Data Science"
print("Welcome,", student_name)
print("You are enrolled in:", course_name)
print("Let's start coding!")
print("Checking if copilot is disbaled")
# Out:
# Welcome, Hadiyah
# You are enrolled in: Data Science
# Let's start coding!
# Checking if copilot is disbaled

# %%
my_name = "Hadiyah Raji"

print("My name is:", my_name)
print("With Python, I want to:")
print("   1: Build uhhh maybe a prayer app")
print("   2: Automate air quality sensors to provide real-time data")
print("   3: Can't think of any other thing yet")
# Out:
# My name is: Hadiyah Raji
# With Python, I want to:
#    1: Build uhhh maybe a prayer app
#    2: Automate air quality sensors to provide real-time data
#    3: Can't think of any other thing yet

# %%
scores = [85, 92, 78, 95, 88]
average = sum(scores) / len(scores)
print("Average score:", average)

message = "python is amazing"
print("Formatted:", message.title())

file_size_mb = 99.9
if file_size_mb > 100:
    print("File is large - consider compressing it")
else:
    print("File size is acceptable.")
# Out:
# Average score: 87.6
# Formatted: Python Is Amazing
# File size is acceptable.

# %%
python_uses = [
    "Web Development",
    "Data Science",
    "Automation",
    "Cybersecurity",
    "Scientific Research",
]

print("Python is used for:")
for use in python_uses:
    print(" -", use)

print("\nTotal domains:", len(python_uses))
# Out:
# Python is used for:
#  - Web Development
#  - Data Science
#  - Automation
#  - Cybersecurity
#  - Scientific Research
#
# Total domains: 5

# %%
# if shoe price is less than 50000, return "buy", if it's greater, return "don't buy"
shoe_price = 51000
if shoe_price < 50000:
    print("Buy")
else:
    print("Don't buy.")
# Out:
# Don't buy.

# %%
name = input("Please enter your name: ")
age = input("Please enter your age: ")

print("\nHello,", name + "!")
print("You are", age, "years old.")
print("Welcome to Python Programming!")
# Out:
# Hello, Hadiyah!
# You are 2 years old.
# Welcome to Python Programming!

# %%
fullname = input("Please enter your full name: ")
level = input("Please enter your level: ")
dept = input("Please enter your department: ")
hobby = input("Please enter your hobby: ")

print("\nWelcome,", name) 
print("You have been enrolled to", level, "level in", dept + ".") 
print("We have noted you are good at", hobby)
# Out:
# Welcome, Hadiyah
# You have been enrolled to 100 level in Data Science.
# We have noted you are good at Coding

# %%
fullname = input("Please enter your full name: ")
level = input("Please enter your level: ")
dept = input("Please enter your department: ")
hobby = input("Please enter your hobby: ")

print("\nWelcome,", name + " You have been enrolled to", level + " level in", dept + ".", "We have noted you are good at", hobby)
# Out:
# Welcome, HadiyahYou have been enrolled to 100level in DS. We have noted you are good at Coding

# %%
acceptable_age = 18
student_age = int(input("Please enter your age: "))

if student_age < acceptable_age:
    print("Welcome")
else:
    print("Not eligible")
# Out:
# Not eligible
